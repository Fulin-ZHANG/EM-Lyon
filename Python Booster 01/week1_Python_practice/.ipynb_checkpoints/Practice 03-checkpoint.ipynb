# %% [markdown]
# <div>
#     <img src="images2/emlyon.png" style="height:60px; float:left; padding-right:10px; margin-top:5px" />
#     <span>
#         <h1 style="padding-bottom:5px;"> AI Booster Week 01 - Python for Data Science </h1>
#         <a href="https://masters.em-lyon.com/fr/msc-in-data-science-artificial-intelligence-strategy">[Emlyon]</a> MSc in Data Science & Artificial Intelligence Strategy (DSAIS) <br/>
#          Paris | © Laureline PINAULT
#     </span>
# </div>

# %% [markdown]
# # Practice - 03: Studying an Olympic dataset with Python and Pandas Library
# The bonus questions are to be skipped. If you have time left at the end of the session or at home you can try them.

# %% [markdown]
# ---
# ### Objectives:
#
# *Discover pandas by practicing over a real dataset.*
#
# ---

# %% [markdown]
# The dataset comes from kaggle, a website containing a lot of open datasets. Its description and some information (how the data has been collected for instance) are available at the following webpage:
# https://www.kaggle.com/datasets/heesoo37/120-years-of-olympic-history-athletes-and-results?resource=download

# %% [markdown]
# ## Part 1: Loading and exploring the data

# %% [markdown]
# __Question 1.__
# Open the csv file in the path location as a pandas dataframe and display it.

# %%
import pandas as pd

path = "./data2/athlete_events.csv"

df = pd.read_csv(path)

# %%
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %% [markdown]
# __Question 2.__
# Use Pandas functions to get some information about the dataset and write a description sentence containing at least nb of rows, nb of columns and nb of values.
#
# Then display the name of the different columns with at least 3 differents methods. Which one(s) also display columns' datatypes?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
df.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %% [markdown]
# __Question 3.__
# Display the 5 first and 10 last records of the dataframe.

# %%
df.head(5)
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df.tail(10)
# Out:
#             ID                          Name Sex   Age  Height  Weight  \
# 271106  135565      Fernando scar Zylberberg   M  27.0   168.0    76.0
# 271107  135566    James Francis "Jim" Zylker   M  21.0   175.0    75.0
# 271108  135567  Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0
# 271109  135567  Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0
# 271110  135568        Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
# 271111  135569                    Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                      Piotr ya   M  27.0   176.0    59.0
# 271113  135570                      Piotr ya   M  27.0   176.0    59.0
# 271114  135571            Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571            Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                  Team  NOC        Games  Year  Season            City  \
# 271106      Argentina  ARG  2004 Summer  2004  Summer          Athina
# ...

# %% [markdown]
# __Question 4.__
# Get statistical indicators of the numeric columns.

# %%
df.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %% [markdown]
# ## Part 2: Modifying the data

# %% [markdown]
# __Question 1.__
# Add the unity measure to the Height and Weight column name (inside parentheses). Make sure that your dataframe is updated.

# %%
df.rename(columns={'Height':'Height(cm)','Weight':'Weight(kg)'},inplace = True)

# %%
df
# Out:
#             ID                      Name Sex   Age  Height(cm)  Weight(kg)  \
# 0            1                 A Dijiang   M  24.0       180.0        80.0
# 1            2                  A Lamusi   M  23.0       170.0        60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0         NaN         NaN
# 3            4      Edgar Lindenau Aabye   M  34.0         NaN         NaN
# 4            5  Christine Jacoba Aaftink   F  21.0       185.0        82.0
# ...        ...                       ...  ..   ...         ...         ...
# 271111  135569                Andrzej ya   M  29.0       179.0        89.0
# 271112  135570                  Piotr ya   M  27.0       176.0        59.0
# 271113  135570                  Piotr ya   M  27.0       176.0        59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0       185.0        96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0       185.0        96.0
#
# ...

# %% [markdown]
# __Question 2.__
# The column Games does not interest us since the information is already contained in the columns Year and Season: remove it. Make sure that your dataframe is updated.

# %%
df.drop(['Games'],axis = 1,inplace = True)

# %%
df
# Out:
#             ID                      Name Sex   Age  Height(cm)  Weight(kg)  \
# 0            1                 A Dijiang   M  24.0       180.0        80.0
# 1            2                  A Lamusi   M  23.0       170.0        60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0         NaN         NaN
# 3            4      Edgar Lindenau Aabye   M  34.0         NaN         NaN
# 4            5  Christine Jacoba Aaftink   F  21.0       185.0        82.0
# ...        ...                       ...  ..   ...         ...         ...
# 271111  135569                Andrzej ya   M  29.0       179.0        89.0
# 271112  135570                  Piotr ya   M  27.0       176.0        59.0
# 271113  135570                  Piotr ya   M  27.0       176.0        59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0       185.0        96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0       185.0        96.0
#
# ...

# %% [markdown]
# __Question 3.__
# We want to add a column that directly give us wether the athlete has won a medal or not. For this we will rename the Medal column 'Medal_type' and add a new column named 'Medal' with this information.

# %%
#First, rename the original Medal column. 
#Make sure that your dataframe is updated.
df.rename(columns={'Medal':'Medal_type'},inplace = True)
df
# Out:
#             ID                      Name Sex   Age  Height(cm)  Weight(kg)  \
# 0            1                 A Dijiang   M  24.0       180.0        80.0
# 1            2                  A Lamusi   M  23.0       170.0        60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0         NaN         NaN
# 3            4      Edgar Lindenau Aabye   M  34.0         NaN         NaN
# 4            5  Christine Jacoba Aaftink   F  21.0       185.0        82.0
# ...        ...                       ...  ..   ...         ...         ...
# 271111  135569                Andrzej ya   M  29.0       179.0        89.0
# 271112  135570                  Piotr ya   M  27.0       176.0        59.0
# 271113  135570                  Piotr ya   M  27.0       176.0        59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0       185.0        96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0       185.0        96.0
#
# ...

# %%
import numpy as np

# %%
#Then we will add the new Medal column.
#df.insert(loc = 13, column = 'Medal', value = np.nan)

#Select the different values for the medals (tip: use the function .unique())
#Then write a function that returns true when the athlete won a medal.
print(df['Medal_type'].unique())

def won_medal(medal_type):
    #df.loc[df['Medal_type'].notna(),'Medal']
    return pd.notna(medal_type)

#Create the new column thanks to the function.
#Don't forget to verify it worked correctly! 
#(tip: use the function .drop_duplicate())
df['Medal'] = df['Medal_type'].apply(won_medal)
df.drop_duplicates(inplace = True)
# Out:
# [nan 'Gold' 'Bronze' 'Silver']

# %%
df
# Out:
#             ID                      Name Sex   Age  Height(cm)  Weight(kg)  \
# 0            1                 A Dijiang   M  24.0       180.0        80.0
# 1            2                  A Lamusi   M  23.0       170.0        60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0         NaN         NaN
# 3            4      Edgar Lindenau Aabye   M  34.0         NaN         NaN
# 4            5  Christine Jacoba Aaftink   F  21.0       185.0        82.0
# ...        ...                       ...  ..   ...         ...         ...
# 271111  135569                Andrzej ya   M  29.0       179.0        89.0
# 271112  135570                  Piotr ya   M  27.0       176.0        59.0
# 271113  135570                  Piotr ya   M  27.0       176.0        59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0       185.0        96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0       185.0        96.0
#
# ...

# %% [markdown]
# __Question 4. (bonus)__
# Remove the sport part from the event column.

# %%
def remove_sport_from_event(event,sport):
    return event.replace(sport,"",1)

df['Event'] = df.apply(lambda row: remove_sport_from_event(row['Event'],row['Sport']),axis=1)

df
# Out:
#             ID                      Name Sex   Age  Height(cm)  Weight(kg)  \
# 0            1                 A Dijiang   M  24.0       180.0        80.0
# 1            2                  A Lamusi   M  23.0       170.0        60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0         NaN         NaN
# 3            4      Edgar Lindenau Aabye   M  34.0         NaN         NaN
# 4            5  Christine Jacoba Aaftink   F  21.0       185.0        82.0
# ...        ...                       ...  ..   ...         ...         ...
# 269726  135569                Andrzej ya   M  29.0       179.0        89.0
# 269727  135570                  Piotr ya   M  27.0       176.0        59.0
# 269728  135570                  Piotr ya   M  27.0       176.0        59.0
# 269729  135571        Tomasz Ireneusz ya   M  30.0       185.0        96.0
# 269730  135571        Tomasz Ireneusz ya   M  34.0       185.0        96.0
#
# ...

# %% [markdown]
# __Question 5.__
# The file "noc_regions.csv" contains the correspondance between the NOC code and the countries. Add this information to the dataframe. Name the new column 'Countries' and place it just after the NOC column.

# %%
noc_df = pd.read_csv('./data2/noc_regions.csv')

# %%
noc_df
# Out:
#      NOC       region                 notes
# 0    AFG  Afghanistan                   NaN
# 1    AHO      Curacao  Netherlands Antilles
# 2    ALB      Albania                   NaN
# 3    ALG      Algeria                   NaN
# 4    AND      Andorra                   NaN
# ..   ...          ...                   ...
# 225  YEM        Yemen                   NaN
# 226  YMD        Yemen           South Yemen
# 227  YUG       Serbia            Yugoslavia
# 228  ZAM       Zambia                   NaN
# 229  ZIM     Zimbabwe                   NaN
#
# [230 rows x 3 columns]

# %%
df = pd.merge(df,noc_df.iloc[:,:2],how ='left',on = 'NOC')

# %%
df
# Out:
#             ID                      Name Sex   Age  Height(cm)  Weight(kg)  \
# 0            1                 A Dijiang   M  24.0       180.0        80.0
# 1            2                  A Lamusi   M  23.0       170.0        60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0         NaN         NaN
# 3            4      Edgar Lindenau Aabye   M  34.0         NaN         NaN
# 4            5  Christine Jacoba Aaftink   F  21.0       185.0        82.0
# ...        ...                       ...  ..   ...         ...         ...
# 269726  135569                Andrzej ya   M  29.0       179.0        89.0
# 269727  135570                  Piotr ya   M  27.0       176.0        59.0
# 269728  135570                  Piotr ya   M  27.0       176.0        59.0
# 269729  135571        Tomasz Ireneusz ya   M  30.0       185.0        96.0
# 269730  135571        Tomasz Ireneusz ya   M  34.0       185.0        96.0
#
# ...

# %%
df.rename(columns = {'region':'Countries'},inplace = True)

# %%
country_col = df.pop('Countries')

# %%
df.insert(df.columns.get_loc('NOC')+1,'Countries',country_col)

# %%
df
# Out:
#             ID                      Name Sex   Age  Height(cm)  Weight(kg)  \
# 0            1                 A Dijiang   M  24.0       180.0        80.0
# 1            2                  A Lamusi   M  23.0       170.0        60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0         NaN         NaN
# 3            4      Edgar Lindenau Aabye   M  34.0         NaN         NaN
# 4            5  Christine Jacoba Aaftink   F  21.0       185.0        82.0
# ...        ...                       ...  ..   ...         ...         ...
# 269726  135569                Andrzej ya   M  29.0       179.0        89.0
# 269727  135570                  Piotr ya   M  27.0       176.0        59.0
# 269728  135570                  Piotr ya   M  27.0       176.0        59.0
# 269729  135571        Tomasz Ireneusz ya   M  30.0       185.0        96.0
# 269730  135571        Tomasz Ireneusz ya   M  34.0       185.0        96.0
#
# ...

# %% [markdown]
# __Question 6.__
# Save your modified dataset in a csv file named 'athlete_events_modified' in the data folder.

# %%
path = "./data2/athlete_events_modified.csv"

df.to_csv(path,index = False)

# %% [markdown]
# ## Part 3: Computing with the data

# %% [markdown]
# __Question 1.__
# Display the average age depending on wether a medal has been won or not. Is there a significative difference?

# %%
path = "./data2/athlete_events_modified.csv"

df2 = pd.read_csv(path)

# %%
won_mean = np.mean(df2.loc[df2['Medal'] == True,'Age'])
notwon_mean = np.mean(df2.loc[df2['Medal'] == False,'Age'])

# %%
print(f"Won mean is {won_mean}, not won mean is {notwon_mean}")
# Out:
# Won mean is 25.923112386026023, not won mean is 25.372174439405164

# %% [markdown]
# __Question 2. (bonus)__
# Find out the yougest athlete(s) to ever win a medal.

# %%
yougest_won = df2[df2['Medal']][df2['Age'] == df2[df2['Medal']]['Age'].min()]
print(yougest_won)
# Out:
#            ID                Name Sex   Age  Height(cm)  Weight(kg)  \
# 142104  71691  Dimitrios Loundras   M  10.0         NaN         NaN
#
#                                  Team  NOC Countries  Year  Season    City  \
# 142104  Ethnikos Gymnastikos Syllogos  GRE    Greece  1896  Summer  Athina
#
#              Sport                                  Event Medal_type  Medal
# 142104  Gymnastics  Gymnastics Men's Parallel Bars, Teams     Bronze   True
# C:\Users\chino\AppData\Local\Temp\ipykernel_16428\3415868528.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   yougest_won = df2[df2['Medal']][df2['Age'] == df2[df2['Medal']]['Age'].min()]

# %%
df_summer = df2.loc[df2['Season'] == 'Summer']

# %%
df_summer
# Out:
#             ID                                Name Sex   Age  Height(cm)  \
# 0            1                           A Dijiang   M  24.0       180.0
# 1            2                            A Lamusi   M  23.0       170.0
# 2            3                 Gunnar Nielsen Aaby   M  24.0         NaN
# 3            4                Edgar Lindenau Aabye   M  34.0         NaN
# 26           8  Cornelia "Cor" Aalten (-Strannood)   F  18.0       168.0
# ...        ...                                 ...  ..   ...         ...
# 269721  135565            Fernando scar Zylberberg   M  27.0       168.0
# 269722  135566          James Francis "Jim" Zylker   M  21.0       175.0
# 269723  135567        Aleksandr Viktorovich Zyuzin   M  24.0       183.0
# 269724  135567        Aleksandr Viktorovich Zyuzin   M  28.0       183.0
# 269725  135568              Olga Igorevna Zyuzkova   F  33.0       171.0
#
#         Weight(kg)            Team  NOC    Countries  Year  Season  \
# ...

# %% [markdown]
# __Question 3.__
# Disply a table with the average height and weight for each sport. Include only the summer seasons of olympic games and sort your result by average height.

# %%
df_summer = df_summer.pivot_table(index = 'Sport', values = ['Height(cm)','Weight(kg)'], aggfunc = 'mean')

# %%
df_summer
# Out:
#                        Height(cm)  Weight(kg)
# Sport
# Archery                173.203085   70.011135
# Art Competitions       174.343750   77.894737
# Athletics              176.256268   69.249287
# Badminton              174.178803   68.171439
# Baseball               182.599291   85.707792
# Basketball             190.869879   85.777053
# Beach Volleyball       186.144954   79.089219
# Boxing                 172.825688   65.249890
# Canoeing               178.539568   76.492615
# Cycling                176.107335   70.066292
# Diving                 166.634264   60.572741
# Equestrianism          174.375272   67.803975
# Fencing                177.164177   71.387538
# Figure Skating         169.500000   65.500000
# Football               175.402195   70.446834
# Golf                   174.290076   71.194444
# Gymnastics             162.936020   56.916553
# Handball               183.384592   81.497151
# Hockey                 173.359676   69.169909
# ...

# %%
df_summer_sorted = df_summer.sort_values(by='Height(cm)', ascending=False)

# %%
df_summer_sorted
# Out:
#                        Height(cm)  Weight(kg)
# Sport
# Basketball             190.869879   85.777053
# Volleyball             186.994822   78.900214
# Beach Volleyball       186.144954   79.089219
# Water Polo             184.834648   84.566446
# Rowing                 184.172222   80.035863
# Handball               183.384592   81.497151
# Baseball               182.599291   85.707792
# Tug-Of-War             182.480000   95.615385
# Motorboating           181.000000   77.000000
# Tennis                 178.898139   70.802291
# Swimming               178.562454   70.588492
# Canoeing               178.539568   76.492615
# Jeu De Paume           178.500000         NaN
# Sailing                178.262199   75.975154
# Modern Pentathlon      177.944316   70.279540
# Fencing                177.164177   71.387538
# Taekwondo              176.750836   68.007475
# Athletics              176.256268   69.249287
# Cycling                176.107335   70.066292
# ...

# %% [markdown]
# ## Part 4: Plotting the data

# %% [markdown]
# __Question 1.__
# - Take back the result of the previous question and display a scatter plot representing the average weight in function of the average height. Don't take into account NaN values. (tip: use the dropna() method for this).
#
# - Does theses values seem to be correlated? Is there some outlier sport? Print a regression line on top of your graph. Change ist color so we can see it well.
#
#     Don't forget to put a title and axes labels to your figure.
#
# __(bonus)__ Change the color and add the labels with the name of sport for the outliers points.

# %%
df_p4 = df_summer_sorted.dropna()

# %%
import matplotlib.pyplot as plt

# %%
x = df_p4['Weight(kg)']
y = df_p4['Height(cm)']
plt.scatter(x,y,color = 'b')
plt.title("Scatter Plot of the weight and the height average")
plt.xlabel("Avg-weight")
plt.ylabel("Avg-height")

linear_model=np.polyfit(x,y,1) # 1代表1次拟合
linear_model_fn=np.poly1d(linear_model)
x_s=np.arange(40,100)
plt.plot(x_s,linear_model_fn(x_s),color="r")

# %%
x = df_p4['Weight(kg)']
y = df_p4['Height(cm)']
plt.scatter(x,y,color = 'b',label = "Data point")

linear_model=np.polyfit(x,y,1) # 1代表1次拟合
linear_model_fn=np.poly1d(linear_model)
x_s=np.arange(40,100)
plt.plot(x_s,linear_model_fn(x_s),color="r", label = 'Linear Fit Line')

outlier_threshold = 3.0

# Identify outliers
outliers = np.where(np.abs(linear_model_fn(x) - y) > outlier_threshold)

# Annotate outliers with sport names
for sport, x_val, y_val in zip(df_p4.index, x, y):
    if np.abs(linear_model_fn(x_val) - y_val) > outlier_threshold:
        plt.scatter(x_val, y_val, color='red', label='Outliers')
        plt.annotate(sport, (x_val, y_val), textcoords='offset points', xytext=(0, 10),
                     ha='center', fontsize=8, color='red')

    
plt.title("Scatter Plot of the weight and the height average")
plt.xlabel("Avg-weight")
plt.ylabel("Avg-height")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have a DataFrame df_p4 with columns 'Weight(kg)' and 'Height(cm)'
# and the index contains the sport names

x = df_p4['Weight(kg)']
y = df_p4['Height(cm)']

# Create a scatter plot for non-outliers
plt.scatter(x, y, color='b', label='Data Points')

# Fit a linear regression line
linear_model = np.polyfit(x, y, 1)
linear_model_fn = np.poly1d(linear_model)
x_s = np.arange(40, 100)
plt.plot(x_s, linear_model_fn(x_s), color="r", label='Linear Fit Line')

# Define a threshold for identifying outliers
outlier_threshold = 3.0

# Annotate and change the color of outliers
legend_flag = False  # Initialize the flag
for sport, x_val, y_val in zip(df_p4.index, x, y):
    if np.abs(linear_model_fn(x_val) - y_val) > outlier_threshold:
        if not legend_flag:  # Check the flag before adding to the legend
            plt.scatter(x_val, y_val, color='red', label='Outliers')
            legend_flag = True  # Set the flag to True after adding to the legend
        else:
            plt.scatter(x_val, y_val, color='red')
        plt.annotate(sport, (x_val, y_val), textcoords='offset points', xytext=(0, 10),
                     ha='center', fontsize=8, color='red')

# Customize the plot
plt.title("Scatter Plot of the Weight and Height Average")
plt.xlabel("Avg-weight")
plt.ylabel("Avg-height")
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# __Question 2. (bonus)__
# Add a color scale representing the number of data we have for each point.

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import gaussian_kde

# Assuming you have a DataFrame df_p4 with columns 'Weight(kg)' and 'Height(cm)'
# and the index contains the sport names

x = df_p4['Weight(kg)']
y = df_p4['Height(cm)']

# Calculate the data density using a 2D kernel density estimation
kde = gaussian_kde([x, y])
density = kde([x, y])

# Create a colormap for the color scale
cmap = plt.get_cmap('viridis')

# Normalize the density values to fit the colormap
norm = plt.Normalize(vmin=density.min(), vmax=density.max())

# Create a scatter plot with colors representing data density
plt.scatter(x, y, c=density, cmap=cmap, s=50, label='Data Points', alpha=0.7)

# Fit a linear regression line
linear_model = np.polyfit(x, y, 1)
linear_model_fn = np.poly1d(linear_model)
x_s = np.arange(40, 100)
plt.plot(x_s, linear_model_fn(x_s), color="r", label='Linear Fit Line')

# Define a threshold for identifying outliers
outlier_threshold = 3.0

# Annotate and change the color of outliers
legend_flag = False  # Initialize the flag
for sport, x_val, y_val, dens in zip(df_p4.index, x, y, density):
    if np.abs(linear_model_fn(x_val) - y_val) > outlier_threshold:
        if not legend_flag:  # Check the flag before adding to the legend
            plt.scatter(x_val, y_val, color='red', label='Outliers')
            legend_flag = True  # Set the flag to True after adding to the legend
        else:
            plt.scatter(x_val, y_val, color='red')
        plt.annotate(sport, (x_val, y_val), textcoords='offset points', xytext=(0, 10),
                     ha='center', fontsize=8, color='red')

# Create a colorbar for the color scale
cbar = plt.colorbar(orientation='vertical', pad=0.04)
cbar.set_label('Data Density')

# Customize the plot
plt.title("Scatter Plot of the Weight and Height Average")
plt.xlabel("Avg-weight")
plt.ylabel("Avg-height")
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# __Question 3. (bonus)__
# Choose 3 sports and represent the evolution of average weight over average height over the years.
#
# Represent them first on 3 different graphs and then on the same one with different colors.
